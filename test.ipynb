# %%
#!/usr/bin/env python
# coding: utf-8
import json
import pandas as pd
import numpy as np
import plotly.express as px
import webbrowser

# %%
import plotly.io as pio
pio.renderers.default = 'png'

# %%
#인도 주 json파일
india_states = json.load(open(r"./states_india.geojson"))
india_states['features'][0].keys()
india_states['features'][7]['properties']
# Out:
# {'cartodb_id': 10, 'state_code': 25, 'st_nm': 'Daman & Diu'}

# %%
#딕셔너리 형태의 주 이름:코드번호
state_id_map ={}

for feature in india_states['features']:
    feature['id'] = feature['properties']['state_code']
    state_id_map[feature['properties']['st_nm']] = feature['id']

# %%
state_id_map
# Out:
# {'Telangana': 0,
#  'Andaman & Nicobar Island': 35,
#  'Andhra Pradesh': 28,
#  'Arunanchal Pradesh': 12,
#  'Assam': 18,
#  'Bihar': 10,
#  'Chhattisgarh': 22,
#  'Daman & Diu': 25,
#  'Goa': 30,
#  'Gujarat': 24,
#  'Haryana': 6,
#  'Himachal Pradesh': 2,
#  'Jammu & Kashmir': 1,
#  'Jharkhand': 20,
#  'Karnataka': 29,
#  'Kerala': 32,
#  'Lakshadweep': 31,
#  'Madhya Pradesh': 23,
#  'Maharashtra': 27,
#  'Manipur': 14,
#  'Chandigarh': 4,
#  'Puducherry': 34,
#  'Punjab': 3,
#  'Rajasthan': 8,
#  'Sikkim': 11,
#  'Tamil Nadu': 33,
#  'Tripura': 16,
#  'Uttar Pradesh': 9,
#  'Uttarakhand': 5,
#  'West Bengal': 19,
#  'Odisha': 21,
#  'Dadara & Nagar Havelli': 26,
#  'Meghalaya': 17,
#  'Mizoram': 15,
#  'Nagaland': 13,
#  'NCT of Delhi': 7}

# %%
india_states['features'][1]['properties']
state_id_map.keys()
len(state_id_map.values())
# Out:
# 36

# %%
import collections
clinic_final = pd.read_csv(r"./Clinic_final2.csv")

clinic_final= collections.Counter(clinic_final['State'])
clinic_final = pd.DataFrame(list(clinic_final.items()), columns=['State','No'])
print(clinic_final)
# Out:
#                                                 State   No
# 0                                   Arunachal Pradesh   96
# 1                                               Assam  186
# 2                                             Manipur  176
# 3                                             Mizoram  160
# 4                                            Nagaland  140
# 5                                              Sikkim  101
# 6                                             Tripura  185
# 7                                         West Bengal  193
# 8                                          Chandigarh  189
# 9                                               Delhi  247
# 10  https://www.google.co.kr/maps/place/Diyos+Hosp...    1
# 11                                            Haryana  222
# 12                                   Himachal Pradesh  202
# 13                                                NaN    5
# 14                                  Jammu and Kashmir  135
# 15                                          Meghalaya  131
# 16                                             Punjab  244
# 17                                      Uttar Pradesh  198
# 18                                        Uttarakhand  151
# 19                                     Andhra Pradesh  223
# 20                                          Karnataka  201
# 21  https://www.google.co.kr/maps/place/Milann+Hos...    1
# 22                                             Kerala  210
# 23                                         Puducherry  142
# 24                                         Tamil Nadu  206
# 25                                          Telangana  246
# 26                                                Goa  199
# 27                                        Maharashtra  235
# 28                                            Gujarat  195
# 29                                     Madhya Pradesh  234
# 30                                          Rajasthan  220

# %%
clinic_final['State'][0] = 'Arunanchal Pradesh'
clinic_final['State'][9] = 'NCT of Delhi'
clinic_final['State'][12] = 'Jammu & Kashmir'
#print(clinic_final)
# Out:
# <ipython-input-39-0c9d966696cf>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-39-0c9d966696cf>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-39-0c9d966696cf>:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
clinic_final['id'] = clinic_final['State'].apply(lambda x: state_id_map[x])
clinic_final
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-346561b99e0b> in <module>
# ----> 1 clinic_final['id'] = clinic_final['State'].apply(lambda x: state_id_map[x])
#       2 clinic_final
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4354         dtype: float64
#    4355         """
# -> 4356         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4357
#    4358     def _reduce(
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply(self)
#    1034             return self.apply_str()
#    1035
# -> 1036         return self.apply_standard()
#    1037
#    1038     def agg(self):
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#    1090                 # List[Union[Callable[..., Any], str]]]]]"; expected
#    1091                 # "Callable[[Any], Any]"
# -> 1092                 mapped = lib.map_infer(
#    1093                     values,
#    1094                     f,  # type: ignore[arg-type]
#
# ~\anaconda3\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-15-346561b99e0b> in <lambda>(x)
# ----> 1 clinic_final['id'] = clinic_final['State'].apply(lambda x: state_id_map[x])
#       2 clinic_final
#
# KeyError: 'https://www.google.co.kr/maps/place/Diyos+Hospital(+A+Multi-+Speciality+Hospital)+Sexual+problem,+Male+infertility,+Kidney+Stone,+Orthopaedics,+Joint+Replacement,+Arthoscopy,+Spine+,+Sports+injury,+Sinus,+Snoring,+Piles,+Hernia,+Gall+Bladder+etc%E2%80%A6/data=!4m5!3m4!1s0x390ce276bef951af:0xf599bb21170262ea!8m2!3d28.5659885!4d77.1945938?authuser=0&hl=en&rclk=1'

# %%
import collections

#csv data  _clinic
hospital_final = pd.read_csv(r"./Hospital_final2.csv")

hospital_final= collections.Counter(hospital_final['State'])
hospital_final = pd.DataFrame(list(hospital_final.items()), columns=['State','No'])
#print(hospital_final)

hospital_final['State'][0] = 'Arunanchal Pradesh'
hospital_final['State'][9] = 'NCT of Delhi'
hospital_final['State'][12] = 'Jammu & Kashmir'

hospital_final['id'] = hospital_final['State'].apply(lambda x: state_id_map[x])



hospital_final
# Out:
# <ipython-input-23-5f1f8e2f895c>:10: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-23-5f1f8e2f895c>:11: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-23-5f1f8e2f895c>:12: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-5f1f8e2f895c> in <module>
#      12 hospital_final['State'][12] = 'Jammu & Kashmir'
#      13
# ---> 14 hospital_final['id'] = hospital_final['State'].apply(lambda x: state_id_map[x])
#      15
#      16
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4354         dtype: float64
#    4355         """
# -> 4356         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4357
#    4358     def _reduce(
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply(self)
#    1034             return self.apply_str()
#    1035
# -> 1036         return self.apply_standard()
#    1037
#    1038     def agg(self):
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#    1090                 # List[Union[Callable[..., Any], str]]]]]"; expected
#    1091                 # "Callable[[Any], Any]"
# -> 1092                 mapped = lib.map_infer(
#    1093                     values,
#    1094                     f,  # type: ignore[arg-type]
#
# ~\anaconda3\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-23-5f1f8e2f895c> in <lambda>(x)
#      12 hospital_final['State'][12] = 'Jammu & Kashmir'
#      13
# ---> 14 hospital_final['id'] = hospital_final['State'].apply(lambda x: state_id_map[x])
#      15
#      16
#
# KeyError: nan

# %%
hospital_final = pd.read_csv(r"./Hospital_final2.csv")

hospital_final= collections.Counter(hospital_final['State'])
hospital_final = pd.DataFrame(list(hospital_final.items()), columns=['State','No'])
print(hospital_final)
# Out:
#                 State   No
# 0   Arunachal Pradesh   97
# 1               Assam  194
# 2             Manipur  176
# 3             Mizoram  150
# 4            Nagaland  162
# 5              Sikkim   68
# 6             Tripura  148
# 7         West Bengal  197
# 8          Chandigarh  171
# 9               Delhi  264
# 10                NaN   13
# 11            Haryana  192
# 12   Himachal Pradesh  214
# 13  Jammu and Kashmir  139
# 14          Meghalaya   71
# 15             Punjab  276
# 16      Uttar Pradesh  196
# 17        Uttarakhand  191
# 18         79.5580178    1
# 19     Andhra Pradesh  160
# 20          Karnataka  204
# 21             Kerala  230
# 22         Puducherry  137
# 23         Tamil Nadu  240
# 24          Telangana  293
# 25                Goa  176
# 26        Maharashtra  237
# 27            Gujarat  225
# 28            Thaltej    1
# 29     Madhya Pradesh  277
# 30          Rajasthan  295

# %%
hospital_final['State'][0] = 'Arunanchal Pradesh'
hospital_final['State'][9] = 'NCT of Delhi'
hospital_final['State'][12] = 'Jammu & Kashmir'

hospital_final['id'] = hospital_final['State'].apply(lambda x: state_id_map[x])
hospital_final
# Out:
#                 State   No
# 0   Arunachal Pradesh   97
# 1               Assam  194
# 2             Manipur  176
# 3             Mizoram  150
# 4            Nagaland  162
# 5              Sikkim   68
# 6             Tripura  148
# 7         West Bengal  197
# 8          Chandigarh  171
# 9               Delhi  264
# 10                NaN   13
# 11            Haryana  192
# 12   Himachal Pradesh  214
# 13  Jammu and Kashmir  139
# 14          Meghalaya   71
# 15             Punjab  276
# 16      Uttar Pradesh  196
# 17        Uttarakhand  191
# 18         79.5580178    1
# 19     Andhra Pradesh  160
# 20          Karnataka  204
# 21             Kerala  230
# 22         Puducherry  137
# 23         Tamil Nadu  240
# 24          Telangana  293
# 25                Goa  176
# 26        Maharashtra  237
# 27            Gujarat  225
# 28            Thaltej    1
# 29     Madhya Pradesh  277
# 30          Rajasthan  295
# <ipython-input-19-10ba6b9672f2>:7: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-19-10ba6b9672f2>:8: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-19-10ba6b9672f2>:9: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-10ba6b9672f2> in <module>
#       9 hospital_final['State'][12] = 'Jammu & Kashmir'
#      10
# ---> 11 hospital_final['id'] = hospital_final['State'].apply(lambda x: state_id_map[x])
#      12 hospital_final
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4354         dtype: float64
#    4355         """
# -> 4356         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4357
#    4358     def _reduce(
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply(self)
#    1034             return self.apply_str()
#    1035
# -> 1036         return self.apply_standard()
#    1037
#    1038     def agg(self):
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#    1090                 # List[Union[Callable[..., Any], str]]]]]"; expected
#    1091                 # "Callable[[Any], Any]"
# -> 1092                 mapped = lib.map_infer(
#    1093                     values,
#    1094                     f,  # type: ignore[arg-type]
#
# ~\anaconda3\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-19-10ba6b9672f2> in <lambda>(x)
#       9 hospital_final['State'][12] = 'Jammu & Kashmir'
#      10
# ---> 11 hospital_final['id'] = hospital_final['State'].apply(lambda x: state_id_map[x])
#      12 hospital_final
#
# KeyError: nan

# %%
import collections

fitness_final = pd.read_csv(r"./Fitness_final2.csv")

fitness_final= collections.Counter(fitness_final['State'])
fitness_final = pd.DataFrame(list(fitness_final.items()), columns=['State','No'])
print(fitness_final)

fitness_final['State'][0] = 'Arunanchal Pradesh'
fitness_final['State'][9] = 'NCT of Delhi'
fitness_final['State'][12] = 'Jammu & Kashmir'

fitness_final['id'] = fitness_final['State'].apply(lambda x: state_id_map[x])
fitness_final
# Out:
#                 State   No
# 0   Arunachal Pradesh   36
# 1               Assam  252
# 2             Manipur  151
# 3             Mizoram  115
# 4            Nagaland  116
# 5              Sikkim  111
# 6             Tripura  111
# 7         West Bengal  214
# 8          Chandigarh  159
# 9               Delhi  209
# 10            Haryana  246
# 11   Himachal Pradesh  224
# 12  Jammu and Kashmir  178
# 13          Meghalaya   66
# 14             Punjab  198
# 15      Uttar Pradesh  151
# 16        Uttarakhand  178
# 17     Andhra Pradesh  193
# 18          Karnataka  246
# 19             Kerala  244
# 20         Puducherry  142
# 21         Tamil Nadu  221
# 22          Telangana  279
# 23                Goa  190
# 24        Maharashtra  155
# 25            Gujarat  213
# 26     Madhya Pradesh  200
# 27          Rajasthan  195
# <ipython-input-21-1fed3159bacc>:9: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-21-1fed3159bacc>:10: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-21-1fed3159bacc>:11: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                  State   No  id
# 0   Arunanchal Pradesh   36  12
# 1                Assam  252  18
# 2              Manipur  151  14
# 3              Mizoram  115  15
# 4             Nagaland  116  13
# 5               Sikkim  111  11
# 6              Tripura  111  16
# 7          West Bengal  214  19
# 8           Chandigarh  159   4
# 9         NCT of Delhi  209   7
# 10             Haryana  246   6
# 11    Himachal Pradesh  224   2
# 12     Jammu & Kashmir  178   1
# 13           Meghalaya   66  17
# 14              Punjab  198   3
# 15       Uttar Pradesh  151   9
# 16         Uttarakhand  178   5
# 17      Andhra Pradesh  193  28
# 18           Karnataka  246  29
# 19              Kerala  244  32
# 20          Puducherry  142  34
# 21          Tamil Nadu  221  33
# 22           Telangana  279   0
# 23                 Goa  190  30
# 24         Maharashtra  155  27
# 25             Gujarat  213  24
# 26      Madhya Pradesh  200  23
# 27           Rajasthan  195   8

# %%
fig = px.choropleth(clinic_final, locations = 'id' , geojson=india_states, color= 'No', scope='asia', title = '지역별 clinic 기관 밀도' )
fig.update_geos(fitbounds='locations', visible = False)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-fd989c2ec9bb> in <module>
# ----> 1 fig = px.choropleth(clinic_final, locations = 'id' , geojson=india_states, color= 'No', scope='asia', title = '지역별 clinic 기관 밀도' )
#       2 fig.update_geos(fitbounds='locations', visible = False)
#       3 fig.show()
#
# ~\anaconda3\lib\site-packages\plotly\express\_chart_types.py in choropleth(data_frame, lat, lon, locations, locationmode, geojson, featureidkey, color, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, hover_name, hover_data, custom_data, animation_frame, animation_group, category_orders, labels, color_discrete_sequence, color_discrete_map, color_continuous_scale, range_color, color_continuous_midpoint, projection, scope, center, fitbounds, basemap_visible, title, template, width, height)
#    1071     colored region mark on a map.
#    1072     """
# -> 1073     return make_figure(
#    1074         args=locals(),
#    1075         constructor=go.Choropleth,
#
# ~\anaconda3\lib\site-packages\plotly\express\_core.py in make_figure(args, constructor, trace_patch, layout_patch)
#    1931     apply_default_cascade(args)
#    1932
# -> 1933     args = build_dataframe(args, constructor)
#    1934     if constructor in [go.Treemap, go.Sunburst, go.Icicle] and args["path"] is not None:
#    1935         args = process_dataframe_hierarchy(args)
#
# ~\anaconda3\lib\site-packages\plotly\express\_core.py in build_dataframe(args, constructor)
#    1403     # now that things have been prepped, we do the systematic rewriting of `args`
#    1404
# -> 1405     df_output, wide_id_vars = process_args_into_dataframe(
#    1406         args, wide_mode, var_name, value_name
#    1407     )
#
# ~\anaconda3\lib\site-packages\plotly\express\_core.py in process_args_into_dataframe(args, wide_mode, var_name, value_name)
#    1205                         if argument == "index":
#    1206                             err_msg += "\n To use the index, pass it in directly as `df.index`."
# -> 1207                         raise ValueError(err_msg)
#    1208                 elif length and len(df_input[argument]) != length:
#    1209                     raise ValueError(
#
# ValueError: Value of 'locations' is not the name of a column in 'data_frame'. Expected one of ['State', 'No'] but received: id

# %%
fig = px.choropleth(hospital_final, locations = 'id' , geojson=india_states, color= 'No', scope='asia', title = '지역별 hospital 기관 밀도' )
fig.update_geos(fitbounds='locations', visible = False)
fig.show()

# %%
fig = px.choropleth(fitness_final, locations = 'id' , geojson=india_states, color= 'No', scope='asia', title = '지역별 fitness 기관 밀도' )
fig.update_geos(fitbounds='locations', visible = False)
fig.show()
