# %%
import pandas as pd

# %%
data=pd.read_csv('Monthly Whole Revenue By Territories Amazon (2017-2021).csv')

# %%
data
# Out:
#           x              y
# 0   2017.10       0.000000
# 1   2017.20       0.000000
# 2   2017.30       0.000000
# 3   2017.40       0.000000
# 4   2017.50       0.000000
# 5   2017.60       0.000000
# 6   2017.70       0.000000
# 7   2017.80       0.000000
# 8   2017.90       0.000000
# 9   2017.10       0.000000
# 10  2017.11       0.000000
# 11  2017.12       0.000000
# 12  2018.10       0.000000
# 13  2018.20       0.000000
# 14  2018.30       0.000000
# 15  2018.40       0.000000
# 16  2018.50       0.000000
# 17  2018.60       0.000000
# 18  2018.70       0.000000
# 19  2018.80       0.000000
# 20  2018.90       0.000000
# 21  2018.10       0.000000
# 22  2018.11       0.000000
# 23  2018.12       0.000000
# 24  2019.10  101516.000000
# 25  2019.20  354469.000000
# 26  2019.30  122755.000000
# 27  2019.40   84024.000000
# 28  2019.50   57796.000000
# 29  2019.60   60222.000000
# 30  2019.70  152826.000000
# 31  2019.80  192168.000000
# 32  2019.90   86807.000000
# ...

# %%
for i in len(data):
    print(data['x'][i])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-28fab4ddeca8> in <module>
# ----> 1 for i in len(data):
#       2     print(data['x'][i])
#
# TypeError: 'int' object is not iterable
